# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('results_contradiction.csv')
vals = Counter([x.split()[0] for x in df['hypothesis'].values.tolist()])

# %%
vals.most_common()
# Out:
# Counter({'lynched': 1,
#          'highjump': 4,
#          'timber': 1,
#          'liter': 1,
#          'canoeing': 1,
#          'bathing': 1,
#          'warlord': 1,
#          'fjord': 1,
#          'sores': 1,
#          'myna': 1,
#          'sniper': 1,
#          'racquetball': 1,
#          'bullhorns': 1,
#          'winnowing': 2,
#          'asteroid': 1,
#          'pastry': 1,
#          'waterpark': 1,
#          'toss': 2,
#          'marsh': 1,
#          'fruit': 1,
#          'mortar': 2,
#          'flames': 1,
#          'skim': 1,
#          'komodo': 1,
#          'output': 1,
#          'hockey': 1,
#          'bathtub': 1,
#          'ballet': 1,
#          'shells': 1,
#          'sitcoms': 1,
#          'muay': 1,
#          'ransom': 1,
#          'beetle': 1,
#          'skillet': 2,
#          'pommel': 1,
#          'swimmingly': 1,
#          'bike': 1,
#          'withdraws': 1,
#          'skull': 1,
#          'agassi': 1,
# ...
